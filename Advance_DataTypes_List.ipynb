# %% [markdown]
# Python Advance Data Types

# %% [markdown]
# 1. List
# 2. Tuple
# 3. Dict
# 4. Set

# %%
#List

x = [10,20,30,40,50]

print(x)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(x, type(x))
# Out:
# [10, 20, 30, 40, 50] <class 'list'>

# %%
y = [10,'vijay', 20, 'Raj', 40]

# %%
print(y)
# Out:
# [10, 'vijay', 20, 'Raj', 40]

# %%
print(y, type(y))
# Out:
# [10, 'vijay', 20, 'Raj', 40] <class 'list'>

# %%
x=[90,40,20,10,30,48]

# %%
print(x[0])
# Out:
# 90

# %%
print(x[5])
# Out:
# 48

# %%
print(x[-2])
# Out:
# 30

# %%
z= x[0:3:2] # 3-1 stop

print(z)
# Out:
# [90, 20]

# %%
#0 start postion
#3 stop but -1 # 3-1= 2
# step - how many steps you want to move

# %%
v = x[::]

print(v)
# Out:
# [90, 40, 20, 10, 30, 48]

# %%
# start - by default is 0
# stop - by default last index
# step - by default 1

# %%
x=[90,40,20,10,30,48]

# %%
x[0] = 100

# %%
print(x)
# Out:
# [100, 40, 20, 10, 30, 48]

# %%
x.append(1000)

# %%
print(x)
# Out:
# [100, 40, 20, 10, 30, 48, 1000]

# %%
x.remove(100)

# %%
print(x)
# Out:
# [40, 20, 10, 30, 48, 1000]

# %%
list1 = [10,20,30,40]
list2 = ['vijay', 'raj', 'rani']

list3 = list1 + list2

print(list3)
# Out:
# [10, 20, 30, 40, 'vijay', 'raj', 'rani']
