# %%
#function
"""
Function is a block of code or sub-program that performs a specific task.
which helps you to amke a code resuseable.
"""

# %%
def main():
  print('enter a number ?')
  n = eval(input())
  if n>0:
    print('positive')
  elif n<0:
    print('negative')
  else:
    print('zero')
  print('program ends:')
main()
# Out:
# enter a number ?
# 0
# zero
# program ends:

# %%
'''
copying and pasting same code, leads to redudant or duplicate code
debugging bit difficult
'''

# %%
def pos_neg_zero(n):
  if n>0:
    print('positive')
  elif n<0:
    print('negative')
  else:
    print('zero')

# %%
def main():
  print('enter a number ?')
  a = eval(input())
  print(pos_neg_zero(a))
main()
# Out:
# enter a number ?
# 10
# positive
# None

# %%
pos_neg_zero(5)
# Out:
# positive

# %%
print(pos_neg_zero(8))
# Out:
# positive
# None

# %%
x = "this is" +pos_neg_zero(15)
# Out:
# positive
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-89618295.py in <cell line: 0>()
# ----> 1 x = "this is" +pos_neg_zero(15)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
def pos_neg_zero(n):
  if n>0:
    return 'positive'
  elif n<0:
     return 'negative'
  else:
    return 'zero'

# %%
x = "this is : " +pos_neg_zero(15)

# %%
print(x)
# Out:
# this is : positive

# %%
print(pos_neg_zero(8))
# Out:
# positive
