# %%
def main():
  print("hellow, world")
main()
# Out:
# hellow, world

# %%
print("hello world")
# Out:
# hello world

# %%
def vijay():
  print("hello world")
vijay()
# Out:
# hello world

# %%
def main():
  print("hello")
main()
# Out:
# hello

# %%
'''from ast import arguments
def: keyword or reserved word - dedicated words in a programming language

main: Name of the function

(): empty arguments function

: - indicates python to expcet an indented block

indeneted block: indentation giving proper number of spaces

print: built in function to print something on screen
'''

# %%
var = 12.5
print(var)
# Out:
# 12.5

# %%
Var=45

var=12.5

Var="Happy"

Var=[1,2,3]

print(var)
# Out:
# 12.5
