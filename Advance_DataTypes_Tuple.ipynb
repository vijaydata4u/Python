# %% [markdown]
# ### **Tuple**

# %%
t1 = ('vijay', 'vinni', 'chinni')
t1
# Out:
# ('vijay', 'vinni', 'chinni')

# %%
print(t1, type(t1))
# Out:
# ('vijay', 'vinni', 'chinni') <class 'tuple'>

# %%
#list we use squre brackets []
# tuple we use parentheses ()

# %%
print(t1[1])
# Out:
# vinni

# %%
t1[-1]
# Out:
# 'chinni'

# %% [markdown]
# #how to modifiy the tuple elements - Change to list, modify and revert it back to tuple

# %%
x =("vinni", "binni", "banny")

y =list(x)

y[1] = 'rinni'

x= tuple(y)

# %%
print(x)
# Out:
# ('vinni', 'rinni', 'banny')

# %%
y =list(x)
y += 'rajni'
x= tuple(y)

# %%
print(x)
# Out:
# ('vinni', 'rinni', 'banny', 'r', 'a', 'j', 'n', 'i')

# %%
tupletest = (10,12,13,15)
tupletest
# Out:
# (10, 12, 13, 15)

# %%
listtest = list(tupletest)
listtest.append(50)
tupletest = tuple(listtest)

# %%
print(tupletest)
# Out:
# (10, 12, 13, 15, 50)

# %%
#join two tuple

t3 =(50,60,70,80)
t4 = ("vijay", "talk", "talks")

t5 = t3 + t4

# %%
t5
# Out:
# (50, 60, 70, 80, 'vijay', 'talk', 'talks')

# %%
#tuples - Server details to acees
# PAN - fixed
# ID - Fixed
