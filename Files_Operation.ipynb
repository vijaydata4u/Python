# %%
"""
Waht is file is? Basic unit of storage

Modes of file operations :

1. Open  - opening a file
2. r - read file  -- Default mode - opens a file for reading
3. a - append content  -- opens a file for appedning the content - if file doesn't exits, it creates a new file
4. w - write content  -- Open a file for writing, creates file if does not exits
5. close - closing the file
6. x - creates a specified file, returns an error if the file exists

Syntax :  Open() - takes two parameters  --filename -- mode

Default mode is read mode
"""

# %%
f6 = open("demo_test.txt", "x")

# %%
f = open("demo.txt", "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1305715824.py in <cell line: 0>()
# ----> 1 f = open("demo.txt", "r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo.txt'

# %%
f = open("demo.txt", "w")

# %%
f.write("hello world")
# Out:
# 11

# %%
f.write("/n my first python file operation:")
# Out:
# 34

# %%
f.close()

# %%
f1 = open("demo.txt", "r")
print(f1.read())
# Out:
# hello world/n my first python file operation:

# %%
f2 = open("demo.txt", "a")

# %%
f2.write('this is my second line of the statment: \n')
# Out:
# 41

# %%
f2.write("my third line: \n")
# Out:
# 16

# %%
f2.close()

# %%
f3 = open("demo.txt")

# %%
print(f3.read())
# Out:
# hello world/n my first python file operation:this is my second line of the statment:
# my third line:

# %%
print(f3.tell())
# Out:
# 102

# %%
print(f3.seek(10))
# Out:
# 10
