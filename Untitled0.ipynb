# %%
#tuple

t1 = (10,12,13,14,15)

print(t1, type(t1))
# Out:
# (10, 12, 13, 14, 15) <class 'tuple'>

# %%
t1[0]
# Out:
# 10

# %%
t1[1][2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2137733959.py in <cell line: 0>()
# ----> 1 t1[1][2]
#
# TypeError: 'int' object is not subscriptable

# %%
t1[0:2]
# Out:
# (10, 12)

# %%
t1[-1]
# Out:
# 15

# %%
t1[:2]
# Out:
# (10, 12)

# %%
t2 =list(t1)
t2[2]=800
t1=tuple(t2)
print(t1)
# Out:
# (10, 12, 800, 14, 15, '2000', 6000)

# %%
print(t1)
# Out:
# (10, 12, 800, 14, 15, '2000', 6000)

# %%
t3 = 7000

t1 = + t3

print(t1)
# Out:
# 7000

# %%
print(t1)
# Out:
# 7000

# %%
t1 = (10,20,30,10,20,30)

t2 = (9000,)

t1 = t2

print(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2692836156.py in <cell line: 0>()
#       3 t2 = (9000,)
#       4
# ----> 5 t1 =+ t2
#       6
#       7 print(t1)
#
# TypeError: bad operand type for unary +: 'tuple'
