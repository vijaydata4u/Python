# %%
'''
constants : (literals) : anything the fixed values
Variable : Var(change) value
'''

# %%
#single comment

"""
double quote comments
"""

'''
single quote comments
'''

#adding two numbers

# %%
#Data type

#why?

1   = 4 bytes
1.5 = 8 bytes
"vijay" = 7 bytes

#there are different types of data types

'''
Numbers
String

'''

'''

***simple : Int, Float, String, Complex, Boolean

***advance : List, Tuple, Dict, Sets

'''

# %%
x= 10

# %%
print(type(x), x)
# Out:
# <class 'int'> 10

# %%
x= 1.5

print(type(x), x)
# Out:
# <class 'float'> 1.5

# %%
x = "vijay tech talks"

# %%
print(type(x), x)
# Out:
# <class 'str'> Vijay

# %%
x = 'vijay'

# %%
print(type(x), x)
# Out:
# <class 'str'> vijay

# %%
x = '''vijay'''

# %%
print(type(x), x)
# Out:
# <class 'str'> vijay

# %%
x= """vijay
tech talks"""
print(type(x), x)
# Out:
# <class 'str'> vijay
# tech talks

# %%
#complex numbers

x = 1+2j

print(type(x), x)
# Out:
# <class 'complex'> (1+2j)

# %%
#Boolean

#True or False

x= False
X = 10

print(type(x), X)
# Out:
# <class 'bool'> 10

# %%
x = "vijay #$ Tech Talks"

# %%
print(type(x), x)
# Out:
# <class 'str'> vijay #$ Tech Talks

# %%
x.upper()
# Out:
# 'VIJAY #$ TECH TALKS'
