# %%
"""
lambda
map
filter

"""

# %%
def sqr(a):
  return a ** 2

sqr(5)
# Out:
# 25

# %%
sqr(3)
# Out:
# 9

# %%
sql1 = lambda a : a ** 2

sql1(5)
# Out:
# 25

# %%
sql1(6)
# Out:
# 36

# %%
a = lambda x1, x2, x3,x4: x1+x2+x3+x4

a(4,2,3,4)
# Out:
# 13

# %%
"""
x = [1,2,3,4,5] #input
y = [3,4,5,6,7] #output
"""

# %%
x = [1,2,3,4,5]
y =[]

for i in x:
  y.append(i+2)

print(y)
# Out:
# [3, 4, 5, 6, 7]

# %%
add2 = lambda n : n+2

# %%
add2(3)
# Out:
# 5

# %%
list(map(add2,x))
# Out:
# [3, 4, 5, 6, 7]

# %%
"""
x = [1,2,3,4,5]

[add2(1), add2(2), add2(3), add2(4), add2(5)]

# %%
y= [10, -20, -30, 40, 50]

"""
if i > 0
"""

f1 = lambda y : y > 0

list(filter(f1,y))
# Out:
# [10, 40, 50]

# %%
list(map(f1,y))
# Out:
# [True, False, False, True, True]
