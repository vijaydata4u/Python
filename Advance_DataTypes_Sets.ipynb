# %%
set1 = {'hello', 'welcome', 'sets'}

# %%
set1
# Out:
# {'hello', 'sets', 'welcome'}

# %%
#unorded, unchangeable, unindexed
#only keys

# %%
print('hello' in set1)
# Out:
# True

# %%
print('sets' not in set1)
# Out:
# False

# %%
#add()

set1.add("vijay")

# %%
print(set1)
# Out:
# {'sets', 'vijay', 'hello', 'welcome'}

# %%
set2 ={10,20,40,50}

set1.update(set2)

# %%
print(set1)
# Out:
# {'hello', 40, 10, 'welcome', 'sets', 50, 20, 'vijay'}

# %%
#remove

set1.remove(40)

# %%
print(set1)
# Out:
# {'hello', 10, 'welcome', 'sets', 50, 20, 'vijay'}

# %%
set3 = set1.union(set2)

# %%
print(set3)
# Out:
# {'hello', 40, 10, 'welcome', 'sets', 50, 20, 'vijay'}

# %%
s1 = {'p1','p2','p3', 'p1','p4','p5'}

s2 = {'p2','p3','p7','p8'}

s1.union(s2)
# Out:
# {'p1', 'p2', 'p3', 'p4', 'p5', 'p7', 'p8'}

# %%
#common product from the both the stores

s1.intersection(s2)
# Out:
# {'p2', 'p3'}

# %%
#difference

s1.difference(s2)
# Out:
# {'p1', 'p4', 'p5'}

# %%
s2.difference(s1)
# Out:
# {'p7', 'p8'}

# %%
set10 = set((10,20,30,40,50))

# %%
set10
# Out:
# {10, 20, 30, 40, 50}
