# %%
dict1 = {

         "name": "vijay",
         "phonenumber": 567484938,
         "phonenumber": 567484938,
         "region": "world",
         "region": "world"
}

# %%
# list []
# tuple ()
# dict {}

print(dict1)
# Out:
# {'name': 'vijay', 'phonenumber': 567484938, 'region': 'world'}

# %%
print(dict1, type(dict1))
# Out:
# {'name': 'vijay', 'phonenumber': 567484938, 'region': 'world'} <class 'dict'>

# %%
len(dict1)
# Out:
# 3

# %%
dict1['name']
# Out:
# 'vijay'

# %%
dict1['vijay']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2707787138.py in <cell line: 0>()
# ----> 1 dict1['vijay']
#
# KeyError: 'vijay'

# %%
#how chnage the dict

print (dict1)
# Out:
# {'name': 'vijay', 'phonenumber': 567484938, 'region': 'world'}

# %%
dict2 = {"name": 'Raju'}

# %%
print(dict2)
# Out:
# {'name': 'Raju'}

# %%
dict2 = {"name": "vijay"}

# %%
dict2
# Out:
# {'name': 'vijay'}

# %%
dict2.update({'name': "rani"})

# %%
dict2
# Out:
# {'name': 'rani'}

# %%
#Keys - int, float, complex, string

# %%
dict3 = {1: ['vijay', 'sf'], 2: ['vinni', 'rf'], 3:['binni', 'gf']}

# %%
print(dict3)
# Out:
# {1: ['vijay', 'sf'], 2: ['vinni', 'rf'], 3: ['binni', 'gf']}

# %%
"name" in dict2
# Out:
# True

# %%
dict3[1][0]
# Out:
# 'vijay'

# %%
dict3[2][0]
# Out:
# 'vinni'

# %%
dict3[3][1]
# Out:
# 'gf'
